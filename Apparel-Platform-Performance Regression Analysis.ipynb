# %% [markdown]
# # 👘 **_Apparel Platform Performance Analysis_**
#
# * Ecommerce company based in New York City that sells clothing online but they also have in-store style and clothing advice sessions.
# * Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want.
#
# The company is trying to decide whether to focus their efforts on their mobile app experience or their website

# %% [markdown]
# ---
# ---
# ## **❇️ IMPORTS:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.dpi'] = 200  #setting dpi to 150

# %% [markdown]
# ---
# ---
# ## **❇️ GETTING DATA:**
#
# Working with Ecommerce Customers csv file from the company.
#
# Present numerical value columns:
#
# * Avg. Session Length: Average session of in-store style advice sessions.
# * Time on App: Average time spent on App in minutes
# * Time on Website: Average time spent on Website in minutes
# * Length of Membership: How many years the customer has been a member.

# %%
df = pd.read_csv('Ecommerce Customers', header = 0, index_col = 0)

# %% [markdown]
# **Check the head of customers, and checking out its info() and describe():**

# %%
df.head()
# Out:
#                                                                          Address  \
# Email
# mstephenson@fernandez.com           835 Frank Tunnel\nWrightmouth, MI 82180-9605
# hduke@hotmail.com                 4547 Archer Common\nDiazchester, CA 06566-8576
# pallen@yahoo.com               24645 Valerie Unions Suite 582\nCobbborough, D...
# riverarebecca@gmail.com         1414 David Throughway\nPort Jason, OH 22070-1220
# mstephens@davidson-herman.com  14023 Rodriguez Passage\nPort Jacobville, PR 3...
#
#                                          Avatar  Avg. Session Length  \
# Email
# mstephenson@fernandez.com                Violet            34.497268
# hduke@hotmail.com                     DarkGreen            31.926272
# pallen@yahoo.com                         Bisque            33.000915
# riverarebecca@gmail.com             SaddleBrown            34.305557
# mstephens@davidson-herman.com  MediumAquaMarine            33.330673
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, mstephenson@fernandez.com to hannahwilson@davidson.com
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Address               500 non-null    object
#  1   Avatar                500 non-null    object
#  2   Avg. Session Length   500 non-null    float64
#  3   Time on App           500 non-null    float64
#  4   Time on Website       500 non-null    float64
#  5   Length of Membership  500 non-null    float64
#  6   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 31.2+ KB

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %% [markdown]
# ---
# ---
#
# ## **❇️ EXPLORATORY DATA ANALYSIS (EDA):**
#
#
#
# **Checking out the correlations and then plotting out few relevant plots:**

# %%
correl = df.corr(numeric_only = True)
correl
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %% [markdown]
# **Joint Plot between "Time on Website" and "Yearly Amount Spent":**

# %%
#Correlation value between Yearly Amount spent & Time on Website : -0.002641
sns.jointplot(x = df['Time on Website'], y = df['Yearly Amount Spent'],height = 5, color = 'royalblue')
plt.suptitle('TIME SPENT ON WEBSITE VS YEARLY AMOUNT SPENT')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Joint Plot between "Time on App" and "Yearly Amount Spent":**

# %%
#Correlation value between Yearly Amount spent & Time on App : 0.499328
sns.jointplot(x = df['Time on App'], y= df['Yearly Amount Spent'], height = 5, color = 'royalblue')
plt.suptitle('TIME SPENT ON APP VS YEARLY AMOUNT SPENT ')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Using jointplot to create a 2D hex bin plot comparing "Time on App" and "Length of Membership":**

# %%
sns.jointplot(kind = 'hex', x = df['Time on App'], y = df['Length of Membership'], height = 5, color = 'royalblue' )
plt.suptitle('TIME ON APP VS LENGTH OF MEMBERSHIP')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Exploring relationships between entire dataset:**

# %%
sns.pairplot(df)

plt.show()

# %%
plt.figure(figsize=(11,6))
sns.heatmap(correl, annot = True, cmap = 'rocket')
plt.suptitle('CORRELATION HEATMAP')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Most correlated feature with "Yearly Amount Spent" ?**
# * Conclusion: Length of Membership

# %% [markdown]
# **Creating a linear model plot of "Yearly Amount Spent" vs. "Length of Membership":**

# %%
sns.lmplot(x = 'Yearly Amount Spent', y = 'Length of Membership', height = 5, data = df)
plt.suptitle('ANALYZING THE MOST CORRELATED FEATURE WITH YEARLY AMOUNT SPENT')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ---
# ## **❇️ DECLARING X AND Y ARRAYS:**
#
# **Setting variable X equal to the numerical features and a variable y equal to the "Yearly Amount Spent" column:**

# %%
#extracting all names of columns
df.columns

# Here "address" and "avatar" feature are not useful as their datatype is Object
# Out:
# Index(['Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
#Declaring x and y arrays:

x = df[['Avg. Session Length' , 'Time on App' , 'Time on Website' , 'Length of Membership']]
y = df['Yearly Amount Spent']

# %% [markdown]
# ---
# ---
# ## **❇️ TRAIN TEST SPLIT:**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 101)

# %% [markdown]
# ---
# ---
# ## **🎯 LINEAR REGRESSION (WITHOUT REGULARIZATION):**

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting Test Data
#
# **Predict the Yearly Amount spent (i.e. y_test), using X_test set of the data:**

# %%
predictions = lm.predict(x_test)

# %% [markdown]
# **Creating a scatterplot of the real test values versus the predicted values of Yearly Amount Spent:**

# %%
sns.scatterplot(x = y_test, y = predictions, color = 'crimson')
plt.xlabel('Observed Value of Yearly Amount Spent')
plt.ylabel('Predicted Value of Yearly Amount Spent')
plt.title('REAL TEST DATA VS PREDICTED VALUES')
plt.show()

# %% [markdown]
# ### Evaluating the Model

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(predictions, y_test))
print('MSE:', metrics.mean_squared_error(predictions, y_test))
print('RMSE', np.sqrt(metrics.mean_squared_error(predictions, y_test)))
# Out:
# MAE: 7.228148653430815
# MSE: 79.81305165097409
# RMSE 8.933815066978614

# %% [markdown]
# ### Residuals
# ****Plotting a histogram of the residuals and making sure it looks normally distributed:****

# %%
sns.distplot((y_test-predictions))
plt.title('RESIDUAL PLOT')

plt.tight_layout()
plt.show()
#this is approxly a normal distribution, thus model is working good with our current set of problem...
# Out:
# /var/folders/8v/bkbfj8z54k5fmfsw_vnhvspc0000gn/T/ipykernel_1279/2135709554.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-predictions))

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## **🎯 LINEAR REGRESSION (WITH L2 REGULARIZATION):**

# %% [markdown]
# * Adding a penalty to large coefficients, if any.
# * Since dataset is not much big, thus setting parameters values as per needed.

# %%
ridge_reg = Ridge(alpha = 1 , max_iter = 1000, tol = 1e-4)

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg.fit(x_train , y_train)
# Out:
# Ridge(alpha=1, max_iter=1000)

# %% [markdown]
# ### Predciting and Evaluating the Model

# %%
pred_with_L2 = ridge_reg.predict(x_test)

# %%
sns.scatterplot(x = y_test, y = pred_with_L2, color = 'crimson')
plt.xlabel('Observed Value of Yearly Amount Spent')
plt.ylabel('Predicted Value of Yearly Amount Spent')
plt.title('REAL TEST DATA VS PREDICTED VALUES')

plt.show()

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(pred_with_L2, y_test))
print('MSE:', metrics.mean_squared_error(pred_with_L2, y_test))
print('RMSE', np.sqrt(metrics.mean_squared_error(pred_with_L2, y_test)))
# Out:
# MAE: 7.246296674867558
# MSE: 80.18696466996937
# RMSE 8.954717453385639

# %% [markdown]
# ### Residuals
# ****Plotting a histogram of the residuals and making sure it looks normally distributed:****

# %%
sns.distplot((y_test-pred_with_L2))
plt.title('RESIDUAL PLOT')

plt.tight_layout()
plt.show()

#this is approxly a normal distribution, thus model is working good with our current set of problem...
# Out:
# /var/folders/8v/bkbfj8z54k5fmfsw_vnhvspc0000gn/T/ipykernel_1279/1653097473.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-pred_with_L2))

# %% [markdown]
# ---
# ---
# ## **🎯 DECISION TREES:**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Evaluating the Model

# %%
pred_dt = dt.predict(x_test)

# %%
sns.scatterplot(x = y_test, y = pred_dt, color = 'crimson')
plt.xlabel('Observed Value of Yearly Amount Spent')
plt.ylabel('Predicted Value of Yearly Amount Spent')
plt.title('REAL TEST DATA VS PREDICTED VALUES')

plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE :", mean_absolute_error(y_test, pred_dt))
print("MSE :", mean_squared_error(y_test, pred_dt))
print("RMSE:", np.sqrt(mean_squared_error(y_test, pred_dt)))
# Out:
# MAE : 23.122298528207455
# MSE : 875.8821629547181
# RMSE: 29.595306434546647

# %% [markdown]
# ### Residuals
# ****Plotting a histogram of the residuals and making sure it looks normally distributed:****

# %%
sns.distplot((y_test-pred_dt))
plt.title('RESIDUAL PLOT')

plt.tight_layout()
plt.show()

#this is approxly a normal distribution, thus model is working good with our current set of problem...
# Out:
# /var/folders/8v/bkbfj8z54k5fmfsw_vnhvspc0000gn/T/ipykernel_1279/678539643.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-pred_dt))

# %% [markdown]
# ---
# ---
# ## **🎯 RANDOM FOREST:**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators = 100)

# %%
rfr.fit(x_train ,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### Evaluating the Model

# %%
pred_rfr = rfr.predict(x_test)

# %%
sns.scatterplot(x = y_test, y = pred_rfr, color = 'crimson')
plt.xlabel('Observed Value of Yearly Amount Spent')
plt.ylabel('Predicted Value of Yearly Amount Spent')
plt.title('REAL TEST DATA VS PREDICTED VALUES')

plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE :", mean_absolute_error(y_test, pred_rfr))
print("MSE :", mean_squared_error(y_test, pred_rfr))
print("RMSE:", np.sqrt(mean_squared_error(y_test, pred_rfr)))
# Out:
# MAE : 14.990347479903175
# MSE : 451.3299348197706
# RMSE: 21.244527173363274

# %% [markdown]
# ### Residuals
# ****Plotting a histogram of the residuals and making sure it looks normally distributed:****

# %%
sns.distplot((y_test-pred_rfr))
plt.title('RESIDUAL PLOT')

plt.tight_layout()
plt.show()

#this is approxly a normal distribution, thus model is working good with our current set of problem...
# Out:
# /var/folders/8v/bkbfj8z54k5fmfsw_vnhvspc0000gn/T/ipykernel_1279/3443919280.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-pred_rfr))

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 📊 **MODEL EVALUATION SUMMARY:**
#
# | Model             | MAE    | RMSE   | MSE    |
# |--------------------|--------|--------|--------|
# | Linear Regression  | 7.23   | 8.93   | 79.81  |
# | Ridge Regression   | 7.25   | 8.95   | 80.19  |
# | Decision Tree      | 22.77  | 29.15  | 849.79 |
# | Random Forest      | 15.13  | 21.11  | 445.56 |
#
# * ✅ **Linear Regression and Ridge performed best on this dataset**, achieving the lowest MAE and RMSE.
# * ❌ **Decision Tree and Random Forest showed higher errors**, suggesting they may have overfit or the data lacked complex patterns requiring tree splits.
# * 🌟 For this platform, **simpler linear models are sufficient to accurately forecast yearly spend**, enabling easier interpretation and actionable marketing strategies. These models can guide targeted promotions and optimize resource allocation without the risk of overfitting.

# %% [markdown]
# ---
# ---
#
# ## 💸 **CONCLUSION BASED ON LINEAR REGRESSION (WITHOUT L2 REGULARIZATION):**
# * Since Linear Regression is more reliable as per above analysis.

# %%
coefficients = pd.DataFrame(index = x.columns, data = ridge_reg.coef_, columns = ['Value of Coefficients'])
coefficients
# Out:
#                       Value of Coefficients
# Avg. Session Length               25.905207
# Time on App                       38.468589
# Time on Website                    0.194365
# Length of Membership              61.104182

# %% [markdown]
# **Interpretting these coefficients?**
#
# - Holding all other features fixed, a 1 unit increase in **Avg. Session Length** is associated with an **increase of 25.98 total dollars spent**.
# - Holding all other features fixed, a 1 unit increase in **Time on App** is associated with an **increase of 38.59 total dollars spent**.
# - Holding all other features fixed, a 1 unit increase in **Time on Website** is associated with an **increase of 0.19 total dollars spent**.
# - Holding all other features fixed, a 1 unit increase in **Length of Membership** is associated with an **increase of 61.27 total dollars spent**.
#
# **CONCLUDING OUT: Should company focus more on their mobile app or on their website?**
# * Conclusion: There are two ways to think about this: Develop the Website to catch up to the performance of the mobile app, or develop the app more since that is what is working better.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🌱 Learnings from This Project
#
# - We discovered that the relationship between customer habits and how much they spend each year is mostly straightforward and linear. Simpler models like Linear and Ridge Regression did the best job, reminding us that sometimes, the simplest tools are the most powerful.
#
# - Trying out more complex models like Decision Trees and Random Forests didn’t actually lead to better predictions here. This taught us that it’s important to let the data guide the choice of model, rather than assuming fancier always means better.
#
# ---
# ---
# # END
